# %% [markdown]
# # WaveformAnalysis 高级示例：插件开发 + 多 run 处理 + 自定义特征
#
# 本 notebook 是一个**独立完整**的高级示例，涵盖：
# - 自定义插件开发（基于 `st_waveforms` 计算特征）
# - 多 run 批处理（并行执行）
# - 自定义特征整合与可视化

# %% [markdown]
# ## 1. 环境与依赖
#
# 请确保已安装 WaveformAnalysis（推荐在项目根目录执行 `./install.sh`）。

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from waveform_analysis import DAQAnalyzer
from waveform_analysis.core.context import Context
from waveform_analysis.core.data.export import BatchProcessor
from waveform_analysis.core.plugins.builtin.cpu import (
    BasicFeaturesPlugin,
    RawFileNamesPlugin,
    WaveformsPlugin,
)
from waveform_analysis.core.plugins.core.base import Option, Plugin

# Matplotlib 中文显示（如有需要）
plt.rcParams["font.sans-serif"] = ["SimHei", "DejaVu Sans"]
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 2. 扫描 DAQ runs
#
# 扫描 `DAQ` 目录下的 runs，并挑选少量 runs 做示例。

# %%
daq_root = "/mnt/data/Run3/DAQ"
da = DAQAnalyzer(daq_root=daq_root, daq_adapter="vx2730")
da.scan_all_runs()

run_ids = list(da.runs.keys())
print(f"Found {len(run_ids)} runs")
run_ids[:5]
# Out:
# Found 44 runs
# ['45V_OV_circulation_CH0_Coincidence_20dB',
#  '46V_OV_circulation_CH0_Coincidence_20dB',
#  '47V_OV_circulation_CH0_Coincidence_20dB',
#  '48V_OV_circulation_CH0_Coincidence_20dB',
#  '49V_OV_circulation_20thr']

# %% [markdown]
# ## 3. 自定义插件：脉冲宽度特征
#
# 基于 `st_waveforms` 的波形数据，计算每个事件的脉冲宽度：
# - `width_samples`：超过阈值的采样点数量
# - `width_ns`：转换为纳秒（基于 `dt_ns`）

# %%
PULSE_WIDTH_DTYPE = np.dtype([
    ("width_samples", "f4"),
    ("width_ns", "f4"),
    ("timestamp", "i8"),
    ("channel", "i2"),
])


class PulseWidthPlugin(Plugin):
    """Compute pulse width above baseline + threshold."""

    provides = "pulse_width"
    depends_on = ["st_waveforms"]
    save_when = "always"
    output_dtype = PULSE_WIDTH_DTYPE
    version = "0.2.0"
    options = {
        "threshold": Option(default=5.0, type=float, help="超过 baseline 的阈值"),
        "dt_ns": Option(default=2.0, type=float, help="采样间隔 (ns)"),
        "min_width": Option(default=1, type=int, help="最小宽度 (采样点)"),
    }

    def compute(self, context, run_id, **kwargs):
        st_waveforms = context.get_data(run_id, "st_waveforms")
        threshold = context.get_config(self, "threshold")
        dt_ns = context.get_config(self, "dt_ns")
        min_width = context.get_config(self, "min_width")

        n_events = len(st_waveforms)
        out = np.zeros(n_events, dtype=PULSE_WIDTH_DTYPE)
        if n_events == 0:
            return out

        waves = st_waveforms["wave"]
        baselines = st_waveforms["baseline"].astype(np.float32)

        if waves.ndim != 2:
            return out

        mask = waves > (baselines[:, None] + threshold)
        widths = mask.sum(axis=1).astype(np.float32)
        widths = np.where(widths < min_width, 0.0, widths)

        out["width_samples"] = widths
        out["width_ns"] = widths * float(dt_ns)
        out["timestamp"] = st_waveforms["timestamp"]
        out["channel"] = st_waveforms["channel"]
        return out

# %% [markdown]
# ## 4. 创建 Context 并注册插件
#
# 注册基础插件 + 自定义插件，并设置统一配置（推荐全局设置 `daq_adapter`）。

# %%
ctx = Context(storage_dir="./strax_data")
ctx.register(
    RawFileNamesPlugin(),
    WaveformsPlugin(),
    BasicFeaturesPlugin(),
    PulseWidthPlugin(),
)
ctx.set_config({
    "data_root": daq_root,
    "daq_adapter": "vx2730",
    "n_channels": 2,
    "show_progress": True,
})
# 自定义插件参数
ctx.set_config(
    {
        "threshold": 6.0,
        "dt_ns": 2.0,
        "min_width": 2,
    },
    plugin_name="pulse_width",
)
print("Context ready.")
# Out:
# Context ready.

# %% [markdown]
# ## 5. 单个 run 试跑与特征整合
#
# 选择一个 run，计算基础特征、脉冲宽度，并构建自定义 DataFrame。

# %%
ctx.show_config()
ctx.list_plugin_configs()
# Out:
# 配置概览
# 缓存目录: /mnt/data/Run3/WaveformAnalysis/strax_data/45V_OV_circulation_CH0_Coincidence_20dB/_cache
# 全局配置项: 2  插件特定配置: 1  未使用配置: 5
#
# 📦 全局配置项
#                             value                    used_by
# key
# daq_adapter              'vx2730'  'raw_files, st_waveforms'
# data_root    '/mnt/data/Run3/DAQ'                'raw_files'
# ⚙️ 插件特定配置
# <style type="text/css">
# #T_a98bd_row0_col0, #T_a98bd_row0_col1, #T_a98bd_row0_col3, #T_a98bd_row0_col4, #T_a98bd_row0_col5, #T_a98bd_row1_col0, #T_a98bd_row1_col1, #T_a98bd_row1_col3, #T_a98bd_row1_col4, #T_a98bd_row1_col5 {
#   background-color: var(--jp-warn-color2, rgba(255, 210, 90, 0.2));
# }
# #T_a98bd_row0_col2, #T_a98bd_row1_col2 {
#   background-color: var(--jp-warn-color2, rgba(255, 210, 90, 0.2));
#   color: var(--jp-error-color1, #c00000);
#   font-weight: 600;
# }
# </style>
# <table id="T_a98bd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a98bd_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_a98bd_level0_col1" class="col_heading level0 col1" >default</th>
#       <th id="T_a98bd_level0_col2" class="col_heading level0 col2" >current</th>
#       <th id="T_a98bd_level0_col3" class="col_heading level0 col3" >status</th>
#       <th id="T_a98bd_level0_col4" class="col_heading level0 col4" >help</th>
#       <th id="T_a98bd_level0_col5" class="col_heading level0 col5" >track</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >plugin</th>
#       <th class="index_name level1" >option</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a98bd_level0_row0" class="row_heading level0 row0" rowspan="3">pulse_width</th>
#       <th id="T_a98bd_level1_row0" class="row_heading level1 row0" >min_width</th>
#       <td id="T_a98bd_row0_col0" class="data row0 col0" >int</td>
#       <td id="T_a98bd_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_a98bd_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_a98bd_row0_col3" class="data row0 col3" >已修改</td>
#       <td id="T_a98bd_row0_col4" class="data row0 col4" >'最小宽度 (采样点)'</td>
#       <td id="T_a98bd_row0_col5" class="data row0 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a98bd_level1_row1" class="row_heading level1 row1" >threshold</th>
#       <td id="T_a98bd_row1_col0" class="data row1 col0" >float</td>
#       <td id="T_a98bd_row1_col1" class="data row1 col1" >5.0</td>
#       <td id="T_a98bd_row1_col2" class="data row1 col2" >6.0</td>
#       <td id="T_a98bd_row1_col3" class="data row1 col3" >已修改</td>
#       <td id="T_a98bd_row1_col4" class="data row1 col4" >'超过 baseline 的阈值'</td>
#       <td id="T_a98bd_row1_col5" class="data row1 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a98bd_level1_row2" class="row_heading level1 row2" >dt_ns</th>
#       <td id="T_a98bd_row2_col0" class="data row2 col0" >float</td>
#       <td id="T_a98bd_row2_col1" class="data row2 col1" >2.0</td>
#       <td id="T_a98bd_row2_col2" class="data row2 col2" >2.0</td>
#       <td id="T_a98bd_row2_col3" class="data row2 col3" >默认</td>
#       <td id="T_a98bd_row2_col4" class="data row2 col4" >'采样间隔 (ns)'</td>
#       <td id="T_a98bd_row2_col5" class="data row2 col5" >True</td>
#     </tr>
#   </tbody>
# </table>
# ⚠️ 未使用配置
# <style type="text/css">
# #T_e4d54_row0_col0, #T_e4d54_row0_col1, #T_e4d54_row1_col0, #T_e4d54_row1_col1, #T_e4d54_row2_col0, #T_e4d54_row2_col1, #T_e4d54_row3_col0, #T_e4d54_row3_col1, #T_e4d54_row4_col0, #T_e4d54_row4_col1 {
#   background-color: var(--jp-error-color2, rgba(255, 120, 120, 0.2));
# }
# </style>
# <table id="T_e4d54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4d54_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_e4d54_level0_col1" class="col_heading level0 col1" >note</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >key</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4d54_level0_row0" class="row_heading level0 row0" >auto_extract_epoch</th>
#       <td id="T_e4d54_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_e4d54_row0_col1" class="data row0 col1" >未被任何已注册插件使用</td>
#     </tr>
#     <tr>
#       <th id="T_e4d54_level0_row1" class="row_heading level0 row1" >epoch_extraction_strategy</th>
#       <td id="T_e4d54_row1_col0" class="data row1 col0" >'auto'</td>
#       <td id="T_e4d54_row1_col1" class="data row1 col1" >未被任何已注册插件使用</td>
#     </tr>
#     <tr>
#       <th id="T_e4d54_level0_row2" class="row_heading level0 row2" >epoch_filename_patterns</th>
#       <td id="T_e4d54_row2_col0" class="data row2 col0" >None</td>
#       <td id="T_e4d54_row2_col1" class="data row2 col1" >未被任何已注册插件使用</td>
#     </tr>
#     <tr>
#       <th id="T_e4d54_level0_row3" class="row_heading level0 row3" >n_channels</th>
#       <td id="T_e4d54_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_e4d54_row3_col1" class="data row3 col1" >未被任何已注册插件使用</td>
#     </tr>
#     <tr>
#       <th id="T_e4d54_level0_row4" class="row_heading level0 row4" >show_progress</th>
#       <td id="T_e4d54_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_e4d54_row4_col1" class="data row4 col1" >未被任何已注册插件使用</td>
#     </tr>
#   </tbody>
# </table>
# 📦 插件概览
#                               class version  \
# plugin
# pulse_width        PulseWidthPlugin   0.2.0
# raw_files        RawFileNamesPlugin   0.0.2
# st_waveforms        WaveformsPlugin   0.5.0
# basic_features  BasicFeaturesPlugin   3.3.0
#
#                                                       description  options  \
# plugin
# pulse_width                                                              3
# raw_files       Scan the data directory and group raw CSV file...        2
# st_waveforms    Extract waveforms from raw CSV files and struc...       10
# basic_features                                                           4
#
#                 modified
# plugin
# pulse_width            2
# raw_files              1
# st_waveforms           1
# basic_features         0
# ⚙️ 配置选项明细
# <style type="text/css">
# #T_c6781_row0_col0, #T_c6781_row0_col1, #T_c6781_row0_col3, #T_c6781_row0_col4, #T_c6781_row0_col5, #T_c6781_row1_col0, #T_c6781_row1_col1, #T_c6781_row1_col3, #T_c6781_row1_col4, #T_c6781_row1_col5, #T_c6781_row2_col0, #T_c6781_row2_col1, #T_c6781_row2_col3, #T_c6781_row2_col4, #T_c6781_row2_col5, #T_c6781_row3_col0, #T_c6781_row3_col1, #T_c6781_row3_col3, #T_c6781_row3_col4, #T_c6781_row3_col5 {
#   background-color: var(--jp-warn-color2, rgba(255, 210, 90, 0.2));
# }
# #T_c6781_row0_col2, #T_c6781_row1_col2, #T_c6781_row2_col2, #T_c6781_row3_col2 {
#   background-color: var(--jp-warn-color2, rgba(255, 210, 90, 0.2));
#   color: var(--jp-error-color1, #c00000);
#   font-weight: 600;
# }
# #T_c6781_row11_col0, #T_c6781_row11_col1, #T_c6781_row11_col2, #T_c6781_row11_col3, #T_c6781_row11_col4, #T_c6781_row11_col5, #T_c6781_row13_col0, #T_c6781_row13_col1, #T_c6781_row13_col2, #T_c6781_row13_col3, #T_c6781_row13_col4, #T_c6781_row13_col5, #T_c6781_row14_col0, #T_c6781_row14_col1, #T_c6781_row14_col2, #T_c6781_row14_col3, #T_c6781_row14_col4, #T_c6781_row14_col5, #T_c6781_row15_col0, #T_c6781_row15_col1, #T_c6781_row15_col2, #T_c6781_row15_col3, #T_c6781_row15_col4, #T_c6781_row15_col5, #T_c6781_row16_col0, #T_c6781_row16_col1, #T_c6781_row16_col2, #T_c6781_row16_col3, #T_c6781_row16_col4, #T_c6781_row16_col5 {
#   background-color: var(--jp-error-color2, rgba(255, 120, 120, 0.2));
# }
# </style>
# <table id="T_c6781">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6781_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_c6781_level0_col1" class="col_heading level0 col1" >default</th>
#       <th id="T_c6781_level0_col2" class="col_heading level0 col2" >current</th>
#       <th id="T_c6781_level0_col3" class="col_heading level0 col3" >status</th>
#       <th id="T_c6781_level0_col4" class="col_heading level0 col4" >help</th>
#       <th id="T_c6781_level0_col5" class="col_heading level0 col5" >track</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >plugin</th>
#       <th class="index_name level1" >option</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6781_level0_row0" class="row_heading level0 row0" rowspan="2">pulse_width</th>
#       <th id="T_c6781_level1_row0" class="row_heading level1 row0" >min_width</th>
#       <td id="T_c6781_row0_col0" class="data row0 col0" >int</td>
#       <td id="T_c6781_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c6781_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_c6781_row0_col3" class="data row0 col3" >已修改</td>
#       <td id="T_c6781_row0_col4" class="data row0 col4" >'最小宽度 (采样点)'</td>
#       <td id="T_c6781_row0_col5" class="data row0 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level1_row1" class="row_heading level1 row1" >threshold</th>
#       <td id="T_c6781_row1_col0" class="data row1 col0" >float</td>
#       <td id="T_c6781_row1_col1" class="data row1 col1" >5.0</td>
#       <td id="T_c6781_row1_col2" class="data row1 col2" >6.0</td>
#       <td id="T_c6781_row1_col3" class="data row1 col3" >已修改</td>
#       <td id="T_c6781_row1_col4" class="data row1 col4" >'超过 baseline 的阈值'</td>
#       <td id="T_c6781_row1_col5" class="data row1 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level0_row2" class="row_heading level0 row2" >raw_files</th>
#       <th id="T_c6781_level1_row2" class="row_heading level1 row2" >data_root</th>
#       <td id="T_c6781_row2_col0" class="data row2 col0" >str</td>
#       <td id="T_c6781_row2_col1" class="data row2 col1" >'DAQ'</td>
#       <td id="T_c6781_row2_col2" class="data row2 col2" >'/mnt/data/Run3/DAQ'</td>
#       <td id="T_c6781_row2_col3" class="data row2 col3" >已修改</td>
#       <td id="T_c6781_row2_col4" class="data row2 col4" >'Root directory for data'</td>
#       <td id="T_c6781_row2_col5" class="data row2 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level0_row3" class="row_heading level0 row3" >st_waveforms</th>
#       <th id="T_c6781_level1_row3" class="row_heading level1 row3" >dt_ns</th>
#       <td id="T_c6781_row3_col0" class="data row3 col0" >int</td>
#       <td id="T_c6781_row3_col1" class="data row3 col1" >None</td>
#       <td id="T_c6781_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_c6781_row3_col3" class="data row3 col3" >已修改</td>
#       <td id="T_c6781_row3_col4" class="data row3 col4" >'Sampling interval in ns for st_waveforms.dt (None=auto from adapter).'</td>
#       <td id="T_c6781_row3_col5" class="data row3 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level0_row4" class="row_heading level0 row4" rowspan="4">basic_features</th>
#       <th id="T_c6781_level1_row4" class="row_heading level1 row4" >area_range</th>
#       <td id="T_c6781_row4_col0" class="data row4 col0" >tuple</td>
#       <td id="T_c6781_row4_col1" class="data row4 col1" >(0, None)</td>
#       <td id="T_c6781_row4_col2" class="data row4 col2" >(0, None)</td>
#       <td id="T_c6781_row4_col3" class="data row4 col3" >默认</td>
#       <td id="T_c6781_row4_col4" class="data row4 col4" >'面积计算范围 (start, end)，end=None 表示积分到波形末端'</td>
#       <td id="T_c6781_row4_col5" class="data row4 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level1_row5" class="row_heading level1 row5" >fixed_baseline</th>
#       <td id="T_c6781_row5_col0" class="data row5 col0" >dict</td>
#       <td id="T_c6781_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_c6781_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_c6781_row5_col3" class="data row5 col3" >默认</td>
#       <td id="T_c6781_row5_col4" class="data row5 col4" >'按通道固定 baseline 值，如 {0: 8192, 1: 8200}。设置后覆盖动态 baseline 用于 height/area 计算。'</td>
#       <td id="T_c6781_row5_col5" class="data row5 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level1_row6" class="row_heading level1 row6" >height_range</th>
#       <td id="T_c6781_row6_col0" class="data row6 col0" >tuple</td>
#       <td id="T_c6781_row6_col1" class="data row6 col1" >(40, 90)</td>
#       <td id="T_c6781_row6_col2" class="data row6 col2" >(40, 90)</td>
#       <td id="T_c6781_row6_col3" class="data row6 col3" >默认</td>
#       <td id="T_c6781_row6_col4" class="data row6 col4" >'高度计算范围 (start, end)'</td>
#       <td id="T_c6781_row6_col5" class="data row6 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level1_row7" class="row_heading level1 row7" >use_filtered</th>
#       <td id="T_c6781_row7_col0" class="data row7 col0" >bool</td>
#       <td id="T_c6781_row7_col1" class="data row7 col1" >False</td>
#       <td id="T_c6781_row7_col2" class="data row7 col2" >False</td>
#       <td id="T_c6781_row7_col3" class="data row7 col3" >默认</td>
#       <td id="T_c6781_row7_col4" class="data row7 col4" >'是否使用 filtered_waveforms（需要先注册 FilteredWaveformsPlugin）'</td>
#       <td id="T_c6781_row7_col5" class="data row7 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level0_row8" class="row_heading level0 row8" >pulse_width</th>
#       <th id="T_c6781_level1_row8" class="row_heading level1 row8" >dt_ns</th>
#       <td id="T_c6781_row8_col0" class="data row8 col0" >float</td>
#       <td id="T_c6781_row8_col1" class="data row8 col1" >2.0</td>
#       <td id="T_c6781_row8_col2" class="data row8 col2" >2.0</td>
#       <td id="T_c6781_row8_col3" class="data row8 col3" >默认</td>
#       <td id="T_c6781_row8_col4" class="data row8 col4" >'采样间隔 (ns)'</td>
#       <td id="T_c6781_row8_col5" class="data row8 col5" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c6781_level0_row9" class="row_heading level0 row9" >raw_files</th>
#       <th id="T_c6781_level1_row9" class="row_heading level1 row9" >daq_adapter</th>
#       <td id="T_c6781_row9_col0" class="data row9 col0" >str</td>
#       <td id="T_c6781_row9_col1" class="data ro
# {'raw_files': {'class': 'RawFileNamesPlugin',
#   'description': 'Scan the data directory and group raw CSV files by channel number.',
#   'version': '0.0.2',
#   'options': {'data_root': {'default': 'DAQ',
#     'type': 'str',
#     'help': 'Root directory for data',
#     'track': True,
#     'current_value': '/mnt/data/Run3/DAQ',
#     'is_default': False},
#    'daq_adapter': {'default': 'vx2730',
#     'type': 'str',
#     'help': "DAQ adapter name (e.g., 'vx2730')",
#     'track': True,
#     'current_value': 'vx2730',
#     'is_default': True}}},
#  'st_waveforms': {'class': 'WaveformsPlugin',
#   'description': 'Extract waveforms from raw CSV files and structure them into NumPy structured arrays.',
#   'version': '0.5.0',
#   'options': {'daq_adapter': {'default': 'vx2730',
#     'type': 'str',
#     'help': "DAQ adapter name (e.g., 'vx2730')",
#     'track': True,
#     'current_value': 'vx2730',
#     'is_default': True},
#    'wave_length': {'default': None,
#     'type': 'int',
#     'help': 'Waveform length (number of sampling points). Automatically detect from the data when None。',
#     'track': True,
#     'current_value': None,
#     'is_default': True},
#    'dt_ns': {'default': None,
#     'type': 'int',
#     'help': 'Sampling interval in ns for st_waveforms.dt (None=auto from adapter).',
#     'track': True,
#     'current_value': 2,
#     'is_default': False},
#    'n_jobs': {'default': None,
#     'type': 'int',
#     'help': 'Number of parallel workers for file-level processing (None=auto, uses min(total_files, 50))',
#     'track': False,
#     'current_value': None,
#     'is_default': True},
#    'use_process_pool': {'default': False,
#     'type': 'bool',
#     'help': 'Whether to use process pool for file-level parallelism (False=thread pool for I/O, True=process pool for CPU-intensive)',
#     'track': False,
#     'current_value': False,
#     'is_default': True},
#    'chunksize': {'default': None,
#     'type': 'int',
#     'help': 'Chunk size for CSV reading (None=read entire file, enables PyArrow; set value to enable chunked reading but disables PyArrow)',
#     'track': False,
#     'current_value': None,
#     'is_default': True},
#    'parse_engine': {'default': 'auto',
#     'type': 'str',
#     'help': 'CSV engine: auto | polars | pyarrow | pandas',
#     'track': False,
#     'current_value': 'auto',
#     'is_default': True},
#    'use_upstream_baseline': {'default': False,
#     'type': 'bool',
#     'help': "Whether to use baseline from upstream plugin (requires 'baseline' data).",
#     'track': True,
#     'current_value': False,
#     'is_default': True},
#    'baseline_samples': {'default': None,
#     'type': 'Any',
#     'help': 'Baseline range: int (sample count from adapter start) or tuple (start, end) relative to samples_start. None=adapter default.',
#     'track': True,
#     'current_value': None,
#     'is_default': True},
#    'streaming_mode': {'default': False,
#     'type': 'bool',
#     'help': 'Enable streaming mode: read files and structure waveforms incrementally to reduce memory usage. When enabled, uses memmap for output to avoid full vstack memory overhead.',
#     'track': False,
#     'current_value': False,
#     'is_default': True}}},
#  'basic_features': {'class': 'BasicFeaturesPlugin',
#   'description': '',
#   'version': '3.3.0',
#   'options': {'height_range': {'default': (40, 90),
#     'type': 'tuple',
#     'help': '高度计算范围 (start, end)',
#     'track': True,
#     'current_value': (40, 90),
#     'is_default': True},
#    'area_range': {'default': (0, None),
#     'type': 'tuple',
#     'help': '面积计算范围 (start, end)，end=None 表示积分到波形末端',
#     'track': True,
#     'current_value': (0, None),
#     'is_default': True},
#    'use_filtered': {'default': False,
#     'type': 'bool',
#     'help': '是否使用 filtered_waveforms（需要先注册 FilteredWaveformsPlugin）',
#     'track': True,
#     'current_value': False,
#     'is_default': True},
#    'fixed_baseline': {'default': None,
#     'type': 'dict',
#     'help': '按通道固定 baseline 值，如 {0: 8192, 1: 8200}。设置后覆盖动态 baseline 用于 height/area 计算。',
#     'track': True,
#     'current_value': None,
#     'is_default': True}}},
#  'pulse_width': {'class': 'PulseWidthPlugin',
#   'description': '',
#   'version': '0.2.0',
#   'options': {'threshold': {'default': 5.0,
#     'type': 'float',
#     'help': '超过 baseline 的阈值',
#     'track': True,
#     'current_value': 6.0,
#     'is_default': False},
#    'dt_ns': {'default': 2.0,
#     'type': 'float',
#     'help': '采样间隔 (ns)',
#     'track': True,
#     'current_value': 2.0,
#     'is_default': True},
#    'min_width': {'default': 1,
#     'type': 'int',
#     'help': '最小宽度 (采样点)',
#     'track': True,
#     'current_value': 2,
#     'is_default': False}}}}

# %%
if len(run_ids) == 0:
    raise RuntimeError("No runs found under DAQ root.")

run_id = run_ids[0]
print(f"Using run: {run_id}")

st_waveforms = ctx.get_data(run_id, "st_waveforms")
basic_features = ctx.get_data(run_id, "basic_features")
pulse_width = ctx.get_data(run_id, "pulse_width")

print(f"总事件数: {len(st_waveforms)}")
channels = np.unique(st_waveforms["channel"])
for ch in channels:
    ch_mask = st_waveforms["channel"] == ch
    print(f"  ch{ch}: {ch_mask.sum()} events")
# Out:
# Using run: 45V_OV_circulation_CH0_Coincidence_20dB
# [+] Running plugin: raw_files (run_id: 45V_OV_circulation_CH0_Coincidence_20dB)
# [+] Running plugin: st_waveforms (run_id: 45V_OV_circulation_CH0_Coincidence_20dB)
# Structuring waveforms (4 channels, workers=4): 100%|██████████| 4/4 [00:00<00:00, 10.79it/s]
# [+] Running plugin: basic_features (run_id: 45V_OV_circulation_CH0_Coincidence_20dB)
# [+] Running plugin: pulse_width (run_id: 45V_OV_circulation_CH0_Coincidence_20dB)
# 总事件数: 1160523
#   ch0: 575903 events
#   ch2: 292340 events
#   ch3: 292280 events

# %%
# 自定义特征整合为 DataFrame（数据已是单个扁平数组）
n_events = min(len(st_waveforms), len(basic_features), len(pulse_width))

if n_events > 0:
    df_custom = pd.DataFrame({
        "timestamp": st_waveforms["timestamp"][:n_events],
        "channel": st_waveforms["channel"][:n_events],
        "height": basic_features["height"][:n_events],
        "area": basic_features["area"][:n_events],
        "width_ns": pulse_width["width_ns"][:n_events],
    }).sort_values("timestamp")
else:
    df_custom = pd.DataFrame()

df_custom.head()
# Out:
#          timestamp  channel     height     area  width_ns
# 0       5377982706        0  38.799999  85887.0     770.0
# 575903  5378027999        2  24.125000   1009.0     298.0
# 575904  5577942873        2  13.275000    285.0     326.0
# 1       5577982439        0  42.974998  86795.0     648.0
# 575905  5877973623        2  15.025000   2472.0     162.0

# %%
# 示例：派生自定义特征并可视化
if len(df_custom) > 0:
    df_custom["area_over_width"] = df_custom["area"] / (df_custom["width_ns"] + 1e-6)
    sample = df_custom.sample(min(len(df_custom), 2000), random_state=42)

    plt.figure(figsize=(6, 4))
    plt.scatter(sample["width_ns"], sample["area"], s=6, alpha=0.4)
    plt.xlabel("Width (ns)")
    plt.ylabel("Area")
    plt.title("Area vs Width (sampled)")
    plt.tight_layout()
    plt.show()
else:
    print("No events to visualize.")

# %% [markdown]
# ## 6. 多 run 批处理
#
# 使用 `BatchProcessor` 并行处理多个 runs，统计每个 run 的脉冲宽度分布。

# %%
if len(run_ids) == 0:
    raise RuntimeError("No runs found for batch processing.")

selected_runs = run_ids[:3]
print("Selected runs:", selected_runs)

processor = BatchProcessor(ctx)
batch_result = processor.process_runs(
    run_ids=selected_runs,
    data_name="pulse_width",
    max_workers=2,
    executor_type="thread",
)

print("Errors:", batch_result["errors"])
# Out:
# Selected runs: ['45V_OV_circulation_CH0_Coincidence_20dB', '46V_OV_circulation_CH0_Coincidence_20dB', '47V_OV_circulation_CH0_Coincidence_20dB']
# Processing pulse_width: 0/3 runs[cache] Loaded 'pulse_width' from disk (run_id: 45V_OV_circulation_CH0_Coincidence_20dB)
# [+] Running plugin: raw_files (run_id: 47V_OV_circulation_CH0_Coincidence_20dB)
# [+] Running plugin: raw_files (run_id: 46V_OV_circulation_CH0_Coincidence_20dB)
# [+] Running plugin: st_waveforms (run_id: 47V_OV_circulation_CH0_Coincidence_20dB)
# [+] Running plugin: st_waveforms (run_id: 46V_OV_circulation_CH0_Coincidence_20dB)
# Parsing files [engine=auto, workers=7, pool=thread]:   0%|          | 0/7 [00:00<?, ?it/s]
# Processing pulse_width: 1/3 runs
# Parsing files [engine=auto, workers=7, pool=thread]:  14%|█▍        | 1/7 [00:02<00:14,  2.42s/it]
# Processing pulse_width: 1/3 runs
# Parsing files [engine=auto, workers=7, pool=thread]:  14%|█▍        | 1/7 [00:06<00:36,  6.01s/it]
# Processing pulse_width: 1/3 runs
# Processing pulse_width: 1/3 runs
# Parsing files [engine=auto, workers=7, pool=thread]:  71%|███████▏  | 5/7 [00:07<00:02,  1.37s/it]
# Processing pulse_width: 1/3 runs
# Parsing files [engine=auto, workers=7, pool=thread]:  86%|████████▌ | 6/7 [00:10<00:01,  1.79s/it]
# Processing pulse_width: 1/3 runs
# Processing pulse_width: 1/3 runs
# Processing pulse_width: 1/3 runs
# Processing pulse_width: 1/3 runs
# Structuring waveforms (4 channels, workers=4):   0%|          | 0/4 [00:00<?, ?it/s]
# Processing pulse_width: 1/3 runs
# Structuring waveforms (4 channels, workers=4): 100%|██████████| 4/4 [00:00<00:00, 10.41it/s]
# Processing pulse_width: 1/3 runs
# Structuring waveforms (4 channels, workers=4):   0%|          | 0/4 [00:00<?, ?it/s]
# Processing pulse_width: 1/3 runs
# Structuring waveforms (4 channels, workers=4): 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Processing pulse_width: 1/3 runs[+] Running plugin: pulse_width (run_id: 47V_OV_circulation_CH0_Coincidence_20dB)
# Processing pulse_width: 1/3 runs[+] Running plugin: pulse_width (run_id: 46V_OV_circulation_CH0_Coincidence_20dB)
# Processing pulse_width: 3/3 runs ✓
# Errors: {}

# %%
# 汇总每个 run 的脉冲宽度统计
summaries = []
for run_id, data in batch_result["results"].items():
    if data is None or len(data) == 0:
        continue
    all_widths = data["width_ns"]
    if len(all_widths) == 0:
        continue
    summaries.append({
        "run_id": run_id,
        "n_events": int(len(all_widths)),
        "median_width_ns": float(np.median(all_widths)),
    })

summary_df = pd.DataFrame(summaries)
summary_df.sort_values("median_width_ns") if len(summary_df) > 0 else summary_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 汇总每个 run 的脉冲宽度统计
#       2 summaries = []
# ----> 3 for run_id, data in batch_result["results"].items():
#       4     if data is None or len(data) == 0:
#       5         continue
#
# NameError: name 'batch_result' is not defined

# %% [markdown]
# ## 7. 下一步建议
#
# - 将自定义插件拆分到独立模块，并使用 `PluginSpec` 做严格校验
