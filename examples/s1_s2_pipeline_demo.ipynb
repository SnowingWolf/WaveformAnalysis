# %% [markdown]
# # S1 / S2 鉴别插件演示
#
# 本 notebook 展示三部分内容：
#
# 1) **WaveformWidthPlugin** 计算宽度
# 2) **GroupedEventsPlugin** 进行事件分组
# 3) **S1S2ClassifierPlugin** 进行 S1 / S2 鉴别
#
# 下面使用**简化的合成数据**演示插件调用方式。真实数据只需替换数据获取部分。

# %%
import numpy as np
import pandas as pd

from waveform_analysis.core.context import Context
from waveform_analysis.core.processing.dtypes import create_record_dtype
from waveform_analysis.core.plugins.builtin.cpu import (
    BasicFeaturesPlugin,
    GroupedEventsPlugin,
    S1S2ClassifierPlugin,
    WaveformWidthPlugin,
)
from waveform_analysis.core.plugins.builtin.cpu.peak_finding import (
    ADVANCED_PEAK_DTYPE,
)

# %% [markdown]
# ## 1) 计算波形宽度 + 基础特征
#
# 这里构造一个简化的 `st_waveforms` 和手工 `signal_peaks`，
# 用于演示 **WaveformWidthPlugin** 和 **BasicFeaturesPlugin**。

# %%
from waveform_analysis import DAQAnalyzer


analyzer = DAQAnalyzer("/mnt/data/Run3/DAQ")  # Initialize DAQAnalyzer for proper waveform handling


analyzer.scan_all_runs()
analyzer.display_overview()
# Out:
# <style type="text/css">
# #T_d0294 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
# }
# #T_d0294_row0_col0, #T_d0294_row0_col3, #T_d0294_row0_col5, #T_d0294_row0_col6, #T_d0294_row0_col7, #T_d0294_row0_col8, #T_d0294_row1_col0, #T_d0294_row1_col3, #T_d0294_row1_col5, #T_d0294_row1_col6, #T_d0294_row1_col7, #T_d0294_row1_col8, #T_d0294_row2_col0, #T_d0294_row2_col3, #T_d0294_row2_col5, #T_d0294_row2_col6, #T_d0294_row2_col7, #T_d0294_row2_col8, #T_d0294_row3_col0, #T_d0294_row3_col3, #T_d0294_row3_col5, #T_d0294_row3_col6, #T_d0294_row3_col7, #T_d0294_row3_col8, #T_d0294_row4_col0, #T_d0294_row4_col3, #T_d0294_row4_col5, #T_d0294_row4_col6, #T_d0294_row4_col7, #T_d0294_row4_col8, #T_d0294_row5_col0, #T_d0294_row5_col3, #T_d0294_row5_col5, #T_d0294_row5_col6, #T_d0294_row5_col7, #T_d0294_row5_col8, #T_d0294_row6_col0, #T_d0294_row6_col3, #T_d0294_row6_col5, #T_d0294_row6_col6, #T_d0294_row6_col7, #T_d0294_row6_col8, #T_d0294_row7_col0, #T_d0294_row7_col3, #T_d0294_row7_col5, #T_d0294_row7_col6, #T_d0294_row7_col7, #T_d0294_row7_col8, #T_d0294_row8_col0, #T_d0294_row8_col3, #T_d0294_row8_col5, #T_d0294_row8_col6, #T_d0294_row8_col7, #T_d0294_row8_col8, #T_d0294_row9_col0, #T_d0294_row9_col3, #T_d0294_row9_col5, #T_d0294_row9_col6, #T_d0294_row9_col7, #T_d0294_row9_col8, #T_d0294_row10_col0, #T_d0294_row10_col3, #T_d0294_row10_col5, #T_d0294_row10_col6, #T_d0294_row10_col7, #T_d0294_row10_col8, #T_d0294_row11_col0, #T_d0294_row11_col3, #T_d0294_row11_col5, #T_d0294_row11_col6, #T_d0294_row11_col7, #T_d0294_row11_col8, #T_d0294_row12_col0, #T_d0294_row12_col3, #T_d0294_row12_col5, #T_d0294_row

#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row0_col4, #T_d0294_row1_col4, #T_d0294_row2_col4, #T_d0294_row3_col1, #T_d0294_row3_col4, #T_d0294_row6_col4, #T_d0294_row7_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row3_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row4_col2 {
#   background-color: #fcab8f;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row4_col4, #T_d0294_row8_col4, #T_d0294_row9_col4, #T_d0294_row10_col4, #T_d0294_row11_col4, #T_d0294_row12_col4, #T_d0294_row15_col4, #T_d0294_row16_col4, #T_d0294_row17_col4, #T_d0294_row18_col4, #T_d0294_row19_col4, #T_d0294_row20_col4, #T_d0294_row21_col4, #T_d0294_row22_col4, #T_d0294_row23_col4, #T_d0294_row24_col4, #T_d0294_row25_col4, #T_d0294_row26_col4, #T_d0294_row28_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row5_col1, #T_d0294_row5_col4, #T_d0294_row13_col1, #T_d0294_row13_col4, #T_d0294_row14_col1, #T_d0294_row14_col4, #T_d0294_row27_col1, #T_d0294_row27_col4, #T_d0294_row29_col1, #T_d0294_row29_col4, #T_d0294_row30_col1, #T_d0294_row30_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row5_col2, #T_d0294_row12_col2, #T_d0294_row13_col2, #T_d0294_row14_col2, #T_d0294_row21_col2, #T_d0294_row24_col2, #T_d0294_row26_col2, #T_d0294_row27_col2, #T_d0294_row28_col2, #T_d0294_row29_col2, #T_d0294_row30_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row6_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row6_col2 {
#   background-color: #ed392b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row7_col1, #T_d0294_row11_col1, #T_d0294_row16_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row7_col2 {
#   background-color: #fee3d6;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row8_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row8_col2 {
#   background-color: #fcad90;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row9_col1, #T_d0294_row18_col1, #T_d0294_row23_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row9_col2 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row10_col1 {
#   background-color: #c6dbef;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row10_col2 {
#   background-color: #fdc5ae;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row11_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row12_col1, #T_d0294_row17_col1, #T_d0294_row20_col1, #T_d0294_row21_col1, #T_d0294_row22_col1, #T_d0294_row24_col1, #T_d0294_row28_col1 {
#   background-color: #e3eef9;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row15_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row15_col2 {
#   background-color: #fa6849;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row16_col2 {
#   background-color: #fdd2bf;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row17_col2 {
#   background-color: #fff2eb;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row18_col2 {
#   background-color: #bd151a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row19_col1, #T_d0294_row25_col1, #T_d0294_row26_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row19_col2 {
#   background-color: #fee1d3;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row20_col2, #T_d0294_row22_col2 {
#   background-color: #fff3ed;
#   color: #000000;
#   text-align: left;
# }
# #T_d0294_row23_col2 {
#   background-color: #b91419;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_d0294_row25_col2 {
#   background-color: #fee3d7;
#   color: #000000;

# %%
run_id = "demo_run"
ctx = Context(storage_dir="./_demo_cache")

ctx.set_config({
    "data_root": "/mnt/data/Run3/DAQ",
    "daq_adapter": "vx2730",  # 文件名包含 @VX2730，需要适配器
    # 配置 raw_files 插件
    "raw_files.n_channels": 2,  # 实际只有 2 个通道有数据
    "raw_files.start_channel_slice": 2,  # 从通道 2 开始（修复：改为 2）
    # 配置 waveforms 插件
    "waveforms.n_channels": 2,  # 实际只有 2 个通道有数据（修复：改为 2）
    "waveforms.start_channel_slice": 2,  # 从通道 2 开始（修复：改为 2）
})


ctx.register(BasicFeaturesPlugin())
ctx.register(WaveformWidthPlugin())
ctx.register(S1S2ClassifierPlugin())


wave_length = 200
dtype = create_record_dtype(wave_length)
st_ch = np.zeros(2, dtype=dtype)

for idx, peak_pos in enumerate([60, 120]):
    wave = np.ones(wave_length, dtype=np.float32) * 10.0
    wave += 90.0 * np.exp(-((np.arange(wave_length) - peak_pos) ** 2) / (2 * 10**2))
    st_ch[idx]["wave"] = wave
    st_ch[idx]["baseline"] = 10.0
    st_ch[idx]["timestamp"] = 1_000_000 + idx * 200_000  # ps
    st_ch[idx]["event_length"] = wave_length
    st_ch[idx]["channel"] = 0

ctx._set_data(run_id, "st_waveforms", [st_ch])

peaks = np.zeros(2, dtype=ADVANCED_PEAK_DTYPE)
for idx, peak_pos in enumerate([60, 120]):
    peaks[idx]["position"] = peak_pos
    peaks[idx]["timestamp"] = st_ch[idx]["timestamp"]
    peaks[idx]["channel"] = 0
    peaks[idx]["event_index"] = idx

ctx._set_data(run_id, "signal_peaks", [peaks])

ctx.set_config({"sampling_rate": 1.0}, plugin_name="waveform_width")

widths = ctx.get_data(run_id, "waveform_width")
features = ctx.get_data(run_id, "basic_features")

widths[0]

# %% [markdown]
# ## 2) S1 / S2 鉴别
#
# 使用 `WaveformWidthPlugin` 的宽度 + `BasicFeaturesPlugin` 的面积/高度进行判断。

# %%
ctx.set_config(
    {
        "width_unit": "ns",
        "s1_width_range": (0.0, 80.0),
        "s2_width_range": (200.0, None),
        "s1_area_range": (0.0, 120.0),
        "s2_area_range": (200.0, None),
        "conflict_policy": "unknown",
    },
    plugin_name="s1_s2",
)

labels = ctx.get_data(run_id, "s1_s2")
labels[0]

# %% [markdown]
# ## 3) 事件分组 (GroupedEventsPlugin)
#
# 这里直接构造一个简化的 `df`，展示分组插件的使用方式。
# `timestamp` 单位为 **ps**，分组窗口参数为 **ns**。

# %%
ctx.register(GroupedEventsPlugin())

df = pd.DataFrame({
    "timestamp": [1_000_000, 1_050_000, 2_000_000, 2_060_000],
    "channel": [0, 1, 0, 1],
    "area": [50.0, 55.0, 500.0, 520.0],
    "height": [10.0, 11.0, 25.0, 27.0],
})

ctx._set_data(run_id, "df", df)
ctx.set_config({"time_window_ns": 100.0}, plugin_name="df_events")
ctx.set_config({"n_channels": 2, "start_channel_slice": 0})

df_events = ctx.get_data(run_id, "df_events")
df_events

# %% [markdown]
# ## 真实数据流程提示
#
# 如果你有真实的 DAQ 数据，只需把 `st_waveforms` / `signal_peaks` / `df` 的构造，
# 替换为真实数据管线（RawFiles → Waveforms → StWaveforms → Features → DataFrame）。
#
# 例如（示意，不执行）：
#
# ```python
# from waveform_analysis.core.plugins.builtin.cpu import (
#     RawFilesPlugin, WaveformsPlugin, SignalPeaksPlugin,
#     BasicFeaturesPlugin, WaveformWidthPlugin, S1S2ClassifierPlugin,
#     DataFramePlugin, GroupedEventsPlugin,
# )
#
# ctx = Context(config={"data_root": "DAQ", "n_channels": 2})
# ctx.register(RawFilesPlugin())
# ctx.register(WaveformsPlugin())
# ctx.register(SignalPeaksPlugin())
# ctx.register(BasicFeaturesPlugin())
# ctx.register(WaveformWidthPlugin())
# ctx.register(S1S2ClassifierPlugin())
# ctx.register(DataFramePlugin())
# ctx.register(GroupedEventsPlugin())
#
# labels = ctx.get_data("run_001", "s1_s2")
# df_events = ctx.get_data("run_001", "df_events")
# ```
